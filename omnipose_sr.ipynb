# %%
# %load_ext autoreload
# %autoreload 2

# %%
from glob import glob
import os
import random
from PIL import Image
from skimage.morphology import label
import numpy as np
import matplotlib.pyplot as plt
import tifffile
from skimage.util import img_as_ubyte
np.random.seed(4)

# %%
# !python -m omnipose --train --use_gpu --dir "C:/Users/robho/OneDrive/Desktop/Uni_Work/Year_4/project2/superres/second_trial/omnipose_training/train/pmc_0.1638_cubic_SR_tiled/" --mask_filter "_masks" --n_epochs 500 --pretrained_model None --save_every 100 --save_each --learning_rate 0.1 --diameter 0 --batch_size 16
# Out:
# 2023-02-28 03:23:45,100 [INFO] No OpenGL_accelerate module loaded: No module named 'OpenGL_accelerate'
# !NEW LOGGING SETUP! To see cellpose progress, set --verbose
# No --verbose => no progress or info printed
# 2023-02-28 03:23:45,731 [INFO] ** TORCH GPU version installed and working. **
# 2023-02-28 03:23:45,731 [INFO] >>>> using GPU
# Omnipose enabled. See Omnipose repo for licencing details.
# 2023-02-28 03:23:45,732 [INFO] Training omni model. Setting nclasses=4, RAdam=True
# 2023-02-28 03:23:46,518 [INFO] not all flows are present, will run flow generation for all images
# ...

# %%
# !python -m omnipose --train --use_gpu --dir "C:/Users/robho/OneDrive/Desktop/Uni_Work/Year_4/project2/superres/second_trial/omnipose_training/train/pmc_0.1092_cubic_SR_tiled/" --mask_filter "_masks" --n_epochs 500 --pretrained_model None --save_every 100 --save_each --learning_rate 0.1 --diameter 0 --batch_size 16
# Out:
# 2023-02-28 03:25:12,912 [INFO] No OpenGL_accelerate module loaded: No module named 'OpenGL_accelerate'
# !NEW LOGGING SETUP! To see cellpose progress, set --verbose
# No --verbose => no progress or info printed
# 2023-02-28 03:25:13,414 [INFO] ** TORCH GPU version installed and working. **
# 2023-02-28 03:25:13,415 [INFO] >>>> using GPU
# Omnipose enabled. See Omnipose repo for licencing details.
# 2023-02-28 03:25:13,415 [INFO] Training omni model. Setting nclasses=4, RAdam=True
# 2023-02-28 03:25:14,316 [INFO] not all flows are present, will run flow generation for all images
# ...
