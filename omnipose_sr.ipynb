# %%
# %load_ext autoreload
# %autoreload 2

# %%
from glob import glob
import os
import random
from PIL import Image
from skimage.morphology import label
import numpy as np
import matplotlib.pyplot as plt
import tifffile
from skimage.util import img_as_ubyte
np.random.seed(4)

# %% [markdown]
# # 100x

# %%
SyMBac_training_data_dir = "superres/first_trial/main_batch/pmc_0.0655/train"
savedir = "superres/first_trial/omnipose_training/pmc_0.0655/train"

# %%
# !python -m omnipose --train --use_gpu --dir "C:/Users/robho/OneDrive/Desktop/Uni Work/Year 4/project2/superres/first_trial/omnipose_training/pmc_0.0655/train" --mask_filter "_masks" --n_epochs 1000 --pretrained_model None --save_every 100 --save_each --learning_rate 0.1 --diameter 0 --batch_size 16
# Out:
# 2023-02-10 18:27:03,591 [INFO] No OpenGL_accelerate module loaded: No module named 'OpenGL_accelerate'
# !NEW LOGGING SETUP! To see cellpose progress, set --verbose
# No --verbose => no progress or info printed
# 2023-02-10 18:27:04,055 [INFO] ** TORCH GPU version installed and working. **
# 2023-02-10 18:27:04,055 [INFO] >>>> using GPU
# Omnipose enabled. See Omnipose repo for licencing details.
# 2023-02-10 18:27:04,055 [INFO] Training omni model. Setting nclasses=4, RAdam=True
# 2023-02-10 18:27:04,874 [INFO] not all flows are present, will run flow generation for all images
# ...

# %% [markdown]
# # 60x

# %%
SyMBac_training_data_dir = "superres/first_trial/main_batch/pmc_0.1092/train"
savedir = "superres/first_trial/omnipose_training/pmc_0.1092/train"

# %%
# !python -m omnipose --train --use_gpu --dir "C:/Users/robho/OneDrive/Desktop/Uni Work/Year 4/project2/superres/first_trial/omnipose_training/pmc_0.1092/train" --mask_filter "_masks" --n_epochs 1000 --pretrained_model None --save_every 100 --save_each --learning_rate 0.1 --diameter 0 --batch_size 16
# Out:
# 2023-02-11 02:26:30,341 [INFO] No OpenGL_accelerate module loaded: No module named 'OpenGL_accelerate'
# !NEW LOGGING SETUP! To see cellpose progress, set --verbose
# No --verbose => no progress or info printed
# 2023-02-11 02:26:30,838 [INFO] ** TORCH GPU version installed and working. **
# 2023-02-11 02:26:30,838 [INFO] >>>> using GPU
# Omnipose enabled. See Omnipose repo for licencing details.
# 2023-02-11 02:26:30,838 [INFO] Training omni model. Setting nclasses=4, RAdam=True
# 2023-02-11 02:26:31,221 [INFO] not all flows are present, will run flow generation for all images
# ...

# %% [markdown]
# # 40x

# %%
SyMBac_training_data_dir = "superres/first_trial/main_batch/pmc_0.1638/train"
savedir = "superres/first_trial/omnipose_training/pmc_0.1638/train"

# %%
# !python -m omnipose --train --use_gpu --dir "C:/Users/robho/OneDrive/Desktop/Uni Work/Year 4/project2/superres/first_trial/omnipose_training/pmc_0.1638/train" --mask_filter "_masks" --n_epochs 1000 --pretrained_model None --save_every 100 --save_each --learning_rate 0.1 --diameter 0 --batch_size 16
# Out:
# 2023-02-11 12:13:23,797 [INFO] No OpenGL_accelerate module loaded: No module named 'OpenGL_accelerate'
# !NEW LOGGING SETUP! To see cellpose progress, set --verbose
# No --verbose => no progress or info printed
# 2023-02-11 12:13:24,260 [INFO] ** TORCH GPU version installed and working. **
# 2023-02-11 12:13:24,260 [INFO] >>>> using GPU
# Omnipose enabled. See Omnipose repo for licencing details.
# 2023-02-11 12:13:24,260 [INFO] Training omni model. Setting nclasses=4, RAdam=True
# 2023-02-11 12:13:24,524 [INFO] not all flows are present, will run flow generation for all images
# ...

# %% [markdown]
# # 60x linear

# %%
SyMBac_training_data_dir = "superres/first_trial/main_batch/pmc_0.1092/train"
savedir = "superres/first_trial/omnipose_training/pmc_0.1092/train"

# %%
# !python -m omnipose --train --use_gpu --dir "C:/Users/robho/OneDrive/Desktop/Uni Work/Year 4/project2/superres/first_trial/omnipose_training/pmc_0.1092_linear/train" --mask_filter "_masks" --n_epochs 500 --pretrained_model None --save_every 100 --save_each --learning_rate 0.1 --diameter 0 --batch_size 16
# Out:
# 2023-02-13 21:39:45,437 [INFO] No OpenGL_accelerate module loaded: No module named 'OpenGL_accelerate'
# !NEW LOGGING SETUP! To see cellpose progress, set --verbose
# No --verbose => no progress or info printed
# 2023-02-13 21:39:45,988 [INFO] ** TORCH GPU version installed and working. **
# 2023-02-13 21:39:45,988 [INFO] >>>> using GPU
# Omnipose enabled. See Omnipose repo for licencing details.
# 2023-02-13 21:39:45,988 [INFO] Training omni model. Setting nclasses=4, RAdam=True
# 2023-02-13 21:39:46,905 [INFO] not all flows are present, will run flow generation for all images
# ...

# %% [markdown]
# # 40x linear

# %%
# !python -m omnipose --train --use_gpu --dir "C:/Users/robho/OneDrive/Desktop/Uni Work/Year 4/project2/superres/first_trial/omnipose_training/pmc_0.1638_linear/train" --mask_filter "_masks" --n_epochs 500 --pretrained_model None --save_every 100 --save_each --learning_rate 0.1 --diameter 0 --batch_size 16
# Out:
# 2023-02-14 01:46:57,529 [INFO] No OpenGL_accelerate module loaded: No module named 'OpenGL_accelerate'
# !NEW LOGGING SETUP! To see cellpose progress, set --verbose
# No --verbose => no progress or info printed
# 2023-02-14 01:46:58,109 [INFO] ** TORCH GPU version installed and working. **
# 2023-02-14 01:46:58,109 [INFO] >>>> using GPU
# Omnipose enabled. See Omnipose repo for licencing details.
# 2023-02-14 01:46:58,109 [INFO] Training omni model. Setting nclasses=4, RAdam=True
# 2023-02-14 01:46:59,063 [INFO] not all flows are present, will run flow generation for all images
# ...

# %% [markdown]
# # 60x sr

# %%
# !python -m omnipose --train --use_gpu --dir "C:/Users/robho/OneDrive/Desktop/Uni Work/Year 4/project2/superres/first_trial/omnipose_training/pmc_0.1092_SR" --mask_filter "_masks" --n_epochs 500 --pretrained_model None --save_every 100 --save_each --learning_rate 0.1 --diameter 0 --batch_size 16
# Out:
# 2023-02-20 02:20:37,419 [INFO] No OpenGL_accelerate module loaded: No module named 'OpenGL_accelerate'
# !NEW LOGGING SETUP! To see cellpose progress, set --verbose
# No --verbose => no progress or info printed
# 2023-02-20 02:20:38,064 [INFO] ** TORCH GPU version installed and working. **
# 2023-02-20 02:20:38,064 [INFO] >>>> using GPU
# Omnipose enabled. See Omnipose repo for licencing details.
# 2023-02-20 02:20:38,064 [INFO] Training omni model. Setting nclasses=4, RAdam=True
# 2023-02-20 02:20:38,821 [INFO] not all flows are present, will run flow generation for all images
# ...

# %% [markdown]
# # 40x sr

# %%
# !python -m omnipose --train --use_gpu --dir "C:/Users/robho/OneDrive/Desktop/Uni Work/Year 4/project2/superres/first_trial/omnipose_training/pmc_0.1638_SR" --mask_filter "_masks" --n_epochs 500 --pretrained_model None --save_every 100 --save_each --learning_rate 0.1 --diameter 0 --batch_size 16
# Out:
# 2023-02-20 06:12:30,982 [INFO] No OpenGL_accelerate module loaded: No module named 'OpenGL_accelerate'
# !NEW LOGGING SETUP! To see cellpose progress, set --verbose
# No --verbose => no progress or info printed
# 2023-02-20 06:12:31,511 [INFO] ** TORCH GPU version installed and working. **
# 2023-02-20 06:12:31,511 [INFO] >>>> using GPU
# Omnipose enabled. See Omnipose repo for licencing details.
# 2023-02-20 06:12:31,511 [INFO] Training omni model. Setting nclasses=4, RAdam=True
# 2023-02-20 06:12:32,319 [INFO] not all flows are present, will run flow generation for all images
# ...
